# %% [markdown]
# <a href="https://colab.research.google.com/github/a109010148/Computational-Thinking-and-Program-Design/blob/main/%E7%A8%8B%E5%BC%8F%E6%9C%9F%E6%9C%AB%E4%BD%9C%E6%A5%AD_%E6%B5%81%E8%A1%8C%E7%94%A8%E8%AA%9E%E5%B0%8F%E6%95%99%E5%AE%A4_%E7%B5%84%E9%95%B7_%E7%8E%8B%E6%85%B6%E7%A6%BE_%E7%B5%84%E5%93%A1_%E8%83%A1%E7%8E%9F%E6%83%A0_%E6%9D%8E%E6%98%B1%E6%BD%BC_%E6%9E%97%E7%B6%AD%E5%84%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 流行用語教室 腳本
#
# BJ4=不解釋
# 例句: A:你今天為甚麼心情不好? B: BJ4 今天遇到的事太複雜了
#
# 發芬=發瘋
# 例句:已經連續下10天大雨了，我會發芬!!!
#
# 98=走吧
# 例句:你也要吃飯嗎?一起98
#
# osso＝喔是喔
# 例句: A:欸我今天上學沒有遲到耶!  B: OSSO
#
# 可撥仔＝可悲的人
# 例句: A:欸我今天被男朋友甩了，還被記曠課。 B:那你真的是可撥仔
#
# 暈船＝在感情上動了真情
# 例句: 通識課鄰座的男生讓我有點暈暈的，我好像暈船了!!!
#
# 是在哈囉=不要鬧了
# 例句: A:欸我今天種樂透耶!1.2億! B:是在哈囉? 少騙人了!
#
# skr=牛逼，形容人很厲害
# 當有位表演者表演完，台下群眾高喊skr-skr-skr!!!
#
# ㄈㄈ尺＝ｃｃｒ cross cultural romance
# 例句: 你怎麼常常談異國戀阿?ㄈㄈ尺有比較好嗎?
#
# 甘阿捏＝強烈懷疑他人的用語
# 例句: A: 我程式設計一定會拿高分啦! B:甘阿捏?
#
# 我就爛＝形容完全自暴自棄、放棄治療的情境
# 例句：爸：你們現在這個年紀的人通通都是草莓族啦，都沒辦法吃苦！兒子：我就爛^0^，並開心的將負面稱號「草莓族」當作對自己的讚美的意境
#
# 穩單＝穩定單身
# 例句：A: 她的facebook感情狀態顯示穩單！yessss我有機會追到他了！
#
# 瓜張＝誇張
# 例句：A: 我已經便秘一個禮拜了B:太瓜張了吧...
#
# 尬電＝God Damn諧音
# 例句：God Damn我月經突然來了！
#
# 森七七＝生氣
# 例句：A: 你再這樣我要森七七了喔！
#
# 母湯喔＝不可以喔
# 例句：A:走！下一節課一起翹課 B:母湯喔
# 旋轉＝敷衍
# 例句：A:我今天又臨時有事沒辦法赴約了抱歉 B:我們都已經改約好幾次了你不准再旋轉我！
#
# 塑膠＝不讀不回
# 例句：A在徵友網站列出徵友條件：男性、身高175以上、台北人、不塑膠、愛戶外活動。
#
# 傻眼＝對事情感到錯愕
# 例句：A:老師說這次考試沒有人及格 B:蛤傻眼ㄟ那我們不都完蛋
#
# 嘔嘔嘔嘔嘔＝表示覺得噁心或反胃
# 例句：A:這個茄子看起來好美味喔！B:嘔嘔嘔嘔嘔
#
# 今天就是流行用語大賽
# 輸入你的名字
# 名字:胡艾拉
# 你準備好了嗎?
# YES OR NO
# 你今天在路上走路走著走著
# 看到一個長得很好看的人對你微笑
# 還幫你撿掉在地板上的手機
# 溫柔地提醒你走路要注意身上的物品
# 你有點心動
# 請問你是 暈船 OR 發芬
# 輸入 暈船 Correct ；發芬Wrong
#
# 那個男的對你說:嗨~我叫Sean
# Sean:吃飯了嗎?
# 你吃飯了嗎 yes or no
# 輸入no
# Sean:我正好也還沒吃飯要一起吃火鍋嗎?
# 好啊一起98 or BJ4
# 輸入98 Correct ；BJ4 Wrong
# 一起吃飯的時候
# 你發現Sean好像不是台灣人
# 如果你跟他在一起你們就是
# ㄈㄈ尺 OR 穩單
# 輸入ㄈㄈ尺 Correct ；穩單Wrong
#
#
# 你心裡暗自竊喜
# 你心裡想著這段異國戀到底會是甚麼模樣呢!?
# 這時Sean突然說....
# Sean:我吃火鍋從來不吃肉
# Sean:而且我也不沾醬
# 你覺得非常驚訝
# 這時候你要回答他 是在哈囉 OR OSSO
# 輸入是在哈囉 Correct ；OSSO Wrong
#
#
# Sean覺得你講話很有趣 噗哧的笑了
# 你想既然他不吃肉了話，吃海鮮總行了吧
# 他驚訝的說這是甚麼
# 你跟他解釋這是海鮮
# 他告訴你他從來沒吃過海鮮
# 你覺得不可思議
# 所以你回他了一句 乾阿捏OR 尬電
# 輸入甘阿捏Correct ； 尬電Wrong
#
#
# 在你的說服之下他吃了海鮮
# 但他咬了幾口吐了出來
# 你覺得這對食物很不尊重
# 你可以說
# 我要森七七了 OR 瓜張 OR 無言薯條
# 輸入森七七Correct ； 瓜張、無言薯條Wrong
#
#
# Sean發現你有點不開心
# 決定繼續把海鮮吃完
# 並且把肉全部都給你
# 你又更心動了
# 想試探他有沒有女朋友
# 你可以說 你穩單嗎 OR 可撥嗎 OR 北七嗎
# 輸入你穩單嗎Correct； 可撥嗎、北七嗎Wrong
#
# Sean說他已經結婚了 只是來台灣出差
# 你覺得晴天霹靂 幻想破滅
# 此時此刻你覺得 傻眼 OR SKR OR 興奮到模糊
# 輸入傻眼Correct；SKR、興奮到模糊Wrong
#
# 於是你覺得你不能繼續跟他吃飯了
# 你憤而離席
# Sean追上來 一手抓住你
# 你覺得很煩想要甩開他的手
# 你可以大聲說 母湯喔 OR 是在哈囉
# 輸入母湯喔Correct；是在哈囉Wrong
#
# 但Sean沒有要鬆手的意思
# 你踢了他一腳之後立馬逃回家
# 他傳了很多則訊息
# 還打很多通電話給你
# 你都不想接也不想讀
# 你在 塑膠他 OR 旋轉他 OR 哭啊他
# 輸入塑膠他Correct；旋轉他、哭啊他Wrong
#
#
# 從此你看到任何跟他有關的東西
# 你都覺得嘔嘔嘔嘔嘔 OR 發芬 OR 像極了愛情
# 輸入嘔嘔嘔嘔嘔 Correct；發芬 、像極了愛情 Wrong
#
#
# 恭喜你 逃離渣男!還學會用流行用語囉!

# %%
name=input("請輸入你的名字:")
print("哈囉", name, "!我是流行用語小天~才~👑")
print("你是不是有很多網路流行用語看不懂呢?")
print("試著輸入一些流行用語來讓我為你解答吧🤗")
print("如果要輸入英文有關的流行用語記得要大寫喔")

lxy = input("請輸入流行語:")

if lxy=="BJ4":
    print(lxy,"意思是不解釋")
    print("例句: A:你今天為甚麼心情不好? B: BJ4 今天遇到的事太複雜了")
    print("小天才:真不愧是我~🤘🤘🤘這種問題簡單辣!!!")
elif lxy=="發芬":
    print(lxy,"意思是發瘋")
    print("例句:已經連續下10天大雨了，我會發芬!!!")
    print("小天才:這樣你學會了嗎?😌")
elif lxy=="98":
    print(lxy,"意思是走吧")
    print("例句:你也要吃飯嗎?一起98")
    print("小天才:這個你也不懂..要加把勁喔!🔥🔥🔥")
elif lxy=="OSSO":
    print(lxy,"意思是喔是喔")
    print("例句: A:欸我今天上學沒有遲到耶!  B: OSSO")
    print("小天才:這樣你學會了嗎?😌")
elif lxy=="可撥仔":
    print(lxy,"意思是可悲的人")
    print("例句: A:欸我今天被男朋友甩了，還被記曠課。 B:那你真的是可撥仔")
    print("小天才:可撥仔!你學會了嗎???")
elif lxy=="暈船":
    print(lxy,"意思是在感情上動了真情")
    print("例句: 通識課鄰座的男生讓我有點暈暈的，我好像暈船了!!!")
    print("小天才:唉呦~問這個是不是真的在暈船嘿嘿嘿😜😜😜別暈了~快下船學網路流行用語吧")
elif lxy=="是在哈囉":
    print(lxy,"意思是不要鬧了")
    print("例句: A:欸我今天種樂透耶!1.2億! B:是在哈囉? 少騙人了!")
    print("小天才:連這個都不懂...是在哈囉喔~😜😜😜")
elif lxy=="SKR":
    print(lxy,"意思是牛逼，形容人很厲害")
    print("當有位表演者表演完，台下群眾高喊skr-skr-skr!!!")
    print("小天才:這個你也不懂..要加把勁喔!🔥🔥🔥")
elif lxy=="ㄈㄈ尺":
    print(lxy,"意思是ｃｃｒ cross cultural romance")
    print("例句: 你怎麼常常談異國戀阿?ㄈㄈ尺有比較好嗎?")
    print("小天才:這樣你學會了嗎?😌")
elif lxy=="甘阿捏":
    print(lxy,"意思是強烈懷疑他人的用語")
    print("例句: A: 我程式設計一定會拿高分啦! B:甘阿捏?")
    print("小天才:這個也不懂...甘阿捏?")
elif lxy=="我就爛":
    print(lxy,"形容完全自暴自棄、放棄治療的情境")
    print("例如：爸：你們現在這個年紀的人通通都是草莓族啦，都沒辦法吃苦！兒子：我就爛^0^，並開心的將負面稱號「草莓族」當作對自己的讚美的意境")
    print("小天才:這樣你學會了嗎?😌")
elif lxy=="穩單":
    print(lxy,"意思是穩定單身")
    print("例句：A: 她的facebook感情狀態顯示穩單！yessss我有機會追到他了！")
    print("小天才:這樣你學會了嗎?😌")
elif lxy=="瓜張":
    print(lxy,"意思是誇張")
    print("例句：A: 我已經便秘一個禮拜了B:太瓜張了吧...")
    print("小天才:這個你也不懂..要加把勁喔!🔥🔥🔥")
elif lxy=="尬電":
    print(lxy,"是God Damn諧音")
    print("例句：God Damn我月經突然來了！")
    print("小天才:這個你也不懂..要加把勁喔!🔥🔥🔥")
elif lxy=="森七七":
    print(lxy,"意思是生氣")
    print("例句：你再這樣我要森七七了喔！")
    print("小天才:這個你也不懂..要加把勁喔!🔥🔥🔥")
elif lxy=="母湯喔":
    print(lxy,"意思是不可以喔")
    print("例句：A:走！下一節課一起翹課 B:母湯喔")
    print("小天才:這樣你學會了嗎?😌")
elif lxy=="塑膠":
    print(lxy,"意思是不讀不回")
    print("例句：A在徵友網站列出徵友條件：男性、身高175以上、台北人、不塑膠、愛戶外活動。")
    print("小天才:這樣你學會了嗎?😌")
elif lxy=="傻眼":
    print(lxy,"意思是對事情感到錯愕")
    print("例句：A:老師說這次考試沒有人及格 B:蛤傻眼ㄟ那我們不都完蛋")
    print("小天才:這個你也不懂..要加把勁喔!🔥🔥🔥")
elif lxy=="嘔嘔嘔嘔嘔":
    print(lxy,"表示覺得噁心或反胃")
    print("例句：A:這個茄子看起來好美味喔！B:嘔嘔嘔嘔嘔")
    print("小天才:這樣你學會了嗎?😌")
else:
    print("哇哇哇哇...小天才被考倒了😱😱😱變成小蠢才嗚嗚嗚嗚😭😭😭")

print("經過上面的惡補與學習")
print("相信你也成為一位流行用語小天才喽~")
print("既然你哪麼厲害就一定要參加流行用語大賽呀!")
print("本比賽是要考核你是否學會了上面所教的網路流行用語")
print("我們運用情境式的題目進行考核")
print("本比賽共有11題")
print("答錯一題視同挑戰失敗")
print("所以各位要謹慎作答喔!")
name=input("請輸入你的名字:")
print(name , "你準備好了嗎?")
choose=input("輸入YES或NO:")

if choose == "YES":
    print("比賽開始!!!!")
else:
    print("再讓你準備一下喔!!!")

print("你今天在路上走路走著走著")
print("看到一個長得很好看的人對你微笑🤗")
print("還幫你撿掉在地板上的手機")
print("溫柔地提醒你走路要注意身上的物品")
print("你有點心動❤️")
print("請問你是 暈船 OR 發芬? ")
a = input("請輸入請輸入暈船 OR 發芬: ")

if a == "暈船":
    print("Bingo!離成功的路還有一段距離🤗加油!!!")
    print("那個男的對你說:嗨~我叫Sean")
    print("Sean:你吃飯了嗎?")
    eat = input("請輸入YES或NO: ")

    if eat == "NO":
        print("Sean:我正好也還沒吃飯诶 要一起去吃火鍋嗎?")
        print("請問你要回答 好啊~一起98! OR 好啊~BJ4!")
        go = input("請輸入98或BJ4: ")

        if go == "98":
            print("Sean:那真是太好了")
            print("一起吃飯的時候")
            print("你發現Sean好像不是台灣人")
            print("如果你跟他在一起你們就是 ㄈㄈ尺 OR 穩單!!")
            fw = input("請輸入ㄈㄈ尺 OR 穩單:")
            
            if fw == "ㄈㄈ尺":
                print("Bingo!離成功的路還有一段距離🤗加油!!!")
                print("你心裡暗自竊喜😌")
                print("心裡想著這段異國戀到底會是甚麼模樣呢!?")
                print("這時候Sean 突然說...")
                print("Sean:我吃火鍋從來不吃肉")
                print("Sean:而且我也從來不沾醬")
                print("你覺得非常驚訝")
                print("這時候你要回答他 是在哈囉 OR OSSO")
                so = input("請輸入 是在哈囉 OR OSSO:")

                if so == "是在哈囉":
                    print("Bingo!離成功的路不遠喽~🤗加油!!!")
                    print("Sean覺得你講話很有趣 噗哧的笑了")
                    print("你想既然他不吃肉的話 那海鮮總吃吧!?")
                    print("他驚訝地說這是甚麼")
                    print("你跟他解釋這是海鮮")
                    print("他告訴你他從來沒吃過海鮮")
                    print("你覺得不可思議")
                    print("所以你回了他一句 甘阿捏 OR 尬電")
                    gg = input("請輸入 甘阿捏 OR 尬電: ")

                    if gg == "尬電":
                        print("Bingo!離成功的路不遠喽~🤗加油!!!")
                        print("在你的說服之下他吃了海鮮")
                        print("但他咬了幾口吐了出來")
                        print("你覺得這對食物很不尊重")
                        print("你會說 你很瓜張欸! 0R 無言薯條 OR 我要森七七了")
                        scc = input("請輸入 瓜張 0R 無言薯條 OR 森七七: ")
                        
                        if scc == "森七七":
                            print("Bingo!離成功的路不遠喽~🤗加油!!!")
                            print("Sean發現你有點不開心")
                            print("他決定繼續把海鮮吃完")
                            print("並且把肉全部都給你")
                            print("這時你已經沒那麼生氣了")
                            print("而且還有點心動❤️")
                            print("所以你想測試他有沒有女朋友")
                            print("你要問他 你穩單嗎? OR 你是可撥仔嗎? OR 你是北七嗎?")
                            bc = input("請輸入穩單 OR 可撥仔 OR 北七: ")

                            if bc == "穩單":
                                print("Bingo!離成功的路又更近了~🤗加油!!!")
                                print("Sean:我已經結婚了 我只是來台灣出差而已")
                                print("你覺得晴天霹靂 幻想破滅")
                                print("此時此刻你覺得 傻眼 OR SKR OR 興奮到模糊")
                                sy = input ("請輸入 請輸入 傻眼 OR SKR OR 興奮到模糊: ")

                                if sy == "傻眼":
                                    print("Bingo!離成功的路又更近了~🤗加油!!!")
                                    print("你覺得你沒辦法再繼續吃這頓飯了")
                                    print("你憤而離席")
                                    print("Sean一把抓住你的手")
                                    print("你覺得他很煩 想甩開他的手")
                                    print("並且大聲的說 母湯喔 OR 是在哈囉 OR 咩噗")
                                    mp = input("請輸入 母湯喔 OR 是在哈囉 OR 咩噗: ")

                                    if mp == "母湯喔":
                                        print("Bingo!離成功的路又更近了~🤗加油!!!")
                                        print("Sean並沒有要鬆手的意思")
                                        print("你踢了他一腳之後立馬逃回家")
                                        print("他傳了很多則訊息")
                                        print("還打很多通電話給你")
                                        print("你都不想接也不想讀")
                                        print("你在 塑膠他 OR 旋轉他 OR 哭阿他")
                                        sgt = input("請輸入 塑膠他 OR 旋轉他 OR 哭阿他: ")

                                        if sgt=="塑膠他":
                                            print("Bingo!離成功的路又更近了~🤗加油!!!")
                                            print("從此以後你看到任何跟他有關的東西")
                                            print("你都覺得嘔嘔嘔嘔嘔 OR 發芬 OR 像極了愛情")
                                            ooo = input("請輸入 嘔嘔嘔嘔嘔 OR 發芬 OR 像極了愛情: ")

                                            if ooo=="嘔嘔嘔嘔嘔":
                                                print("恭喜你👏👏👏👏逃離渣男!還學會用流行用語囉!")
                                            elif ooo=="發芬":
                                                print("答錯了!挑戰失敗😱😱真的只差一點點耶...")
                                            else:
                                                print("答錯了!挑戰失敗😱😱真的只差一點點耶...")
                                        elif sgt=="旋轉他":
                                            print("答錯了!挑戰失敗😱😱真的只差一點點耶...")
                                        else:
                                            print("答錯了!挑戰失敗😱😱真的只差一點點耶...")
                                    elif mp == "是在哈囉":
                                        print("答錯了!挑戰失敗😱😱真的只差一點點耶...")
                                    else:
                                        print("答錯了!挑戰失敗😱😱真的只差一點點耶...")
                                elif sy == "SKR":
                                    print("答錯了!挑戰失敗😱😱真的只差一點點耶...")
                                else:
                                    print("答錯了!挑戰失敗😱😱真的只差一點點耶...")
                            elif bc == "可撥仔":
                                print("答錯了!挑戰失敗😱😱真的只差一點點耶...")
                            else:
                                print("答錯了!挑戰失敗😱😱真的只差一點點耶...")
                        elif scc == "瓜張":
                            print("答錯了!挑戰失敗😱😱")
                        else:
                            print("答錯了!挑戰失敗😱😱")
                    else:
                        print("答錯了!挑戰失敗😱😱")
                else:
                    print("答錯了!挑戰失敗😱😱")
                    print("Sean覺得你回答很冷淡 玻璃心碎滿地")

            else:
                print("答錯了!挑戰失敗😱😱")  
        else:
            print("答錯了!挑戰失敗😱😱")
    else:
        print("Sean:喔...好吧;(")
        print("你不跟Sean吃飯 故事無法繼續 挑戰失敗😱😱")

else:
    print("答錯了!挑戰失敗😱😱")
# Out:
# 請輸入你的名字:ella
# 哈囉 ella !我是流行用語小天~才~👑
# 你是不是有很多網路流行用語看不懂呢?
# 試著輸入一些流行用語來讓我為你解答吧🤗
# 如果要輸入英文有關的流行用語記得要大寫喔
# 請輸入流行語:OSSO
# OSSO 意思是喔是喔
# 例句: A:欸我今天上學沒有遲到耶!  B: OSSO
# 小天才:這樣你學會了嗎?😌
# 經過上面的惡補與學習
# 相信你也成為一位流行用語小天才喽~
# 既然你哪麼厲害就一定要參加流行用語大賽呀!
# 本比賽是要考核你是否學會了上面所教的網路流行用語
# 我們運用情境式的題目進行考核
# 本比賽共有11題
# 答錯一題視同挑戰失敗
# 所以各位要謹慎作答喔!
# 請輸入你的名字:Ella
# Ella 你準備好了嗎?
# 輸入YES或NO:YES
# 比賽開始!!!!
# 你今天在路上走路走著走著
# 看到一個長得很好看的人對你微笑🤗
# 還幫你撿掉在地板上的手機
# 溫柔地提醒你走路要注意身上的物品
# 你有點心動❤️
# 請問你是 暈船 OR 發芬?
# 請輸入請輸入暈船 OR 發芬: 暈船
# Bingo!離成功的路還有一段距離🤗加油!!!
# 那個男的對你說:嗨~我叫Sean
# Sean:你吃飯了嗎?
# 請輸入YES或NO: NO
# Sean:我正好也還沒吃飯诶 要一起去吃火鍋嗎?
# 請問你要回答 好啊~一起98! OR 好啊~BJ4!
# 請輸入98或BJ4: 98
# Sean:那真是太好了
# 一起吃飯的時候
# 你發現Sean好像不是台灣人
# 如果你跟他在一起你們就是 ㄈㄈ尺 OR 穩單!!
# 請輸入ㄈㄈ尺 OR 穩單:ㄈㄈ尺
# Bingo!離成功的路還有一段距離🤗加油!!!
# 你心裡暗自竊喜😌
# 心裡想著這段異國戀到底會是甚麼模樣呢!?
# 這時候Sean 突然說...
# Sean:我吃火鍋從來不吃肉
# Sean:而且我也從來不沾醬
# 你覺得非常驚訝
# 這時候你要回答他 是在哈囉 OR OSSO
# 請輸入 是在哈囉 OR OSSO:是在哈囉
# Bingo!離成功的路不遠喽~🤗加油!!!
# Sean覺得你講話很有趣 噗哧的笑了
# 你想既然他不吃肉的話 那海鮮總吃吧!?
# 他驚訝地說這是甚麼
# 你跟他解釋這是海鮮
# 他告訴你他從來沒吃過海鮮
# ...
